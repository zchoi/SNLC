# %%
import h5py
f = h5py.File('data/test2015.hdf5','r')
print(f.keys())
print(f['image_bb'])
print(f['image_features'])
# Out:
# <KeysViewHDF5 ['image_bb', 'image_features', 'spatial_features']>
# <HDF5 dataset "image_bb": shape (81434, 36, 4), type "<f4">
# <HDF5 dataset "image_features": shape (81434, 36, 2048), type "<f4">

# %%
import pickle
f = pickle.load(open('data/test2015_ids.pkl','rb'))
print(len(f))
# Out:
# 81434
